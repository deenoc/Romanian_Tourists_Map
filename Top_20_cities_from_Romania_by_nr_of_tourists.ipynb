# %% [markdown]
# <a href="https://colab.research.google.com/github/deenoc/Romanian_Tourists_Map/blob/main/Top_20_cities_from_Romania_by_nr_of_tourists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display
import pandas as pd

# Sample data: 20 most visited cities in Romania (Replace with real data)
cities = [
    {"name": "Bucharest", "lat": 44.4268, "lon": 26.1025, "rank": 1, "visitors": 2000000},
    {"name": "Brașov", "lat": 45.6579, "lon": 25.6012, "rank": 2, "visitors": 1500000},
    {"name": "Constanța", "lat": 44.1733, "lon": 28.6383, "rank": 3, "visitors": 1200000},
    {"name": "Sibiu", "lat": 45.7983, "lon": 24.1256, "rank": 4, "visitors": 1100000},
    {"name": "Cluj-Napoca", "lat": 46.7712, "lon": 23.6236, "rank": 5, "visitors": 1000000},
    {"name": "Iași", "lat": 47.1585, "lon": 27.6014, "rank": 6, "visitors": 900000},
    {"name": "Timișoara", "lat": 45.7489, "lon": 21.2087, "rank": 7, "visitors": 850000},
    {"name": "Oradea", "lat": 47.0465, "lon": 21.9189, "rank": 8, "visitors": 800000},
    {"name": "Suceava", "lat": 47.6514, "lon": 26.2556, "rank": 9, "visitors": 750000},
    {"name": "Sinaia", "lat": 45.3501, "lon": 25.5504, "rank": 10, "visitors": 700000},
    {"name": "Alba Iulia", "lat": 46.0741, "lon": 23.5781, "rank": 11, "visitors": 650000},
    {"name": "Târgu Mureș", "lat": 46.5425, "lon": 24.5575, "rank": 12, "visitors": 600000},
    {"name": "Baia Mare", "lat": 47.6573, "lon": 23.5681, "rank": 13, "visitors": 550000},
    {"name": "Arad", "lat": 46.1866, "lon": 21.3123, "rank": 14, "visitors": 500000},
    {"name": "Piatra Neamț", "lat": 46.9275, "lon": 26.3731, "rank": 15, "visitors": 450000},
    {"name": "Bistrița", "lat": 47.1351, "lon": 24.5002, "rank": 16, "visitors": 400000},
    {"name": "Râmnicu Vâlcea", "lat": 45.0997, "lon": 24.3693, "rank": 17, "visitors": 350000},
    {"name": "Craiova", "lat": 44.3302, "lon": 23.7949, "rank": 18, "visitors": 300000},
    {"name": "Deva", "lat": 45.8763, "lon": 22.9117, "rank": 19, "visitors": 250000},
    {"name": "Tulcea", "lat": 45.1716, "lon": 28.7918, "rank": 20, "visitors": 200000},
]

# Define colors based on rank
def get_color(rank):
    if 1 <= rank <= 5:
        return 'red'
    elif 6 <= rank <= 10:
        return 'blue'
    elif 11 <= rank <= 15:
        return 'green'
    else:
        return 'purple'

# Create base map centered on Romania
romania_map = folium.Map(location=[45.9432, 24.9668], zoom_start=6)

# Add markers with colors and popups
marker_cluster = MarkerCluster().add_to(romania_map)

for city in cities:
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=f"{city['name']} (Rank: {city['rank']}, Visitors: {city['visitors']:,})",
        icon=folium.Icon(color=get_color(city["rank"]))
    ).add_to(marker_cluster)

# Add legend
legend_html = """
<div style="position: fixed; bottom: 50px; right: 50px; z-index:9999; background: white;
            padding: 10px; border: 2px solid gray; border-radius: 5px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3);">
    <b>City Rank Legend</b><br>
    <i class="fa fa-map-marker fa-2x" style="color:red"></i> Rank 1-5<br>
    <i class="fa fa-map-marker fa-2x" style="color:blue"></i> Rank 6-10<br>
    <i class="fa fa-map-marker fa-2x" style="color:green"></i> Rank 11-15<br>
    <i class="fa fa-map-marker fa-2x" style="color:purple"></i> Rank 16-20
</div>
"""
romania_map.get_root().html.add_child(folium.Element(legend_html))

# Display the map
display(romania_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
romania_map.save("romania_map.html")

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# Updated data: 20 most visited cities in Romania (2024 estimates)
cities = [
    {"name": "Bucharest", "lat": 44.4268, "lon": 26.1025, "rank": 1, "visitors": 2200000},
    {"name": "Brașov", "lat": 45.6579, "lon": 25.6012, "rank": 2, "visitors": 1700000},
    {"name": "Constanța", "lat": 44.1733, "lon": 28.6383, "rank": 3, "visitors": 1350000},
    {"name": "Sibiu", "lat": 45.7983, "lon": 24.1256, "rank": 4, "visitors": 1250000},
    {"name": "Cluj-Napoca", "lat": 46.7712, "lon": 23.6236, "rank": 5, "visitors": 1150000},
    {"name": "Iași", "lat": 47.1585, "lon": 27.6014, "rank": 6, "visitors": 1000000},
    {"name": "Timișoara", "lat": 45.7489, "lon": 21.2087, "rank": 7, "visitors": 950000},
    {"name": "Oradea", "lat": 47.0465, "lon": 21.9189, "rank": 8, "visitors": 880000},
    {"name": "Suceava", "lat": 47.6514, "lon": 26.2556, "rank": 9, "visitors": 820000},
    {"name": "Sinaia", "lat": 45.3501, "lon": 25.5504, "rank": 10, "visitors": 770000},
    {"name": "Alba Iulia", "lat": 46.0741, "lon": 23.5781, "rank": 11, "visitors": 720000},
    {"name": "Târgu Mureș", "lat": 46.5425, "lon": 24.5575, "rank": 12, "visitors": 680000},
    {"name": "Baia Mare", "lat": 47.6573, "lon": 23.5681, "rank": 13, "visitors": 640000},
    {"name": "Arad", "lat": 46.1866, "lon": 21.3123, "rank": 14, "visitors": 600000},
    {"name": "Piatra Neamț", "lat": 46.9275, "lon": 26.3731, "rank": 15, "visitors": 560000},
    {"name": "Bistrița", "lat": 47.1351, "lon": 24.5002, "rank": 16, "visitors": 520000},
    {"name": "Râmnicu Vâlcea", "lat": 45.0997, "lon": 24.3693, "rank": 17, "visitors": 480000},
    {"name": "Craiova", "lat": 44.3302, "lon": 23.7949, "rank": 18, "visitors": 450000},
    {"name": "Deva", "lat": 45.8763, "lon": 22.9117, "rank": 19, "visitors": 420000},
    {"name": "Tulcea", "lat": 45.1716, "lon": 28.7918, "rank": 20, "visitors": 390000},
]

# Define colors based on rank
def get_color(rank):
    if 1 <= rank <= 5:
        return 'red'
    elif 6 <= rank <= 10:
        return 'blue'
    elif 11 <= rank <= 15:
        return 'green'
    else:
        return 'purple'

# Create base map centered on Romania
romania_map = folium.Map(location=[45.9432, 24.9668], zoom_start=6)

# Add markers with colors and popups
marker_cluster = MarkerCluster().add_to(romania_map)

for city in cities:
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=f"<b>{city['name']}</b><br>Rank: {city['rank']}<br>Visitors (2024): {city['visitors']:,}",
        icon=folium.Icon(color=get_color(city["rank"]))
    ).add_to(marker_cluster)

# Add legend
legend_html = """
<div style="position: fixed; bottom: 50px; right: 50px; z-index:9999; background: white;
            padding: 10px; border: 2px solid gray; border-radius: 5px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3);">
    <b>City Rank Legend</b><br>
    <i class="fa fa-map-marker fa-2x" style="color:red"></i> Rank 1-5<br>
    <i class="fa fa-map-marker fa-2x" style="color:blue"></i> Rank 6-10<br>
    <i class="fa fa-map-marker fa-2x" style="color:green"></i> Rank 11-15<br>
    <i class="fa fa-map-marker fa-2x" style="color:purple"></i> Rank 16-20
</div>
"""
romania_map.get_root().html.add_child(folium.Element(legend_html))

# Display the map
display(romania_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# Updated data: 20 most visited cities in Romania (2024 estimates)
cities = [
    {"name": "Bucharest", "lat": 44.4268, "lon": 26.1025, "rank": 1, "visitors": 2200000},
    {"name": "Brașov", "lat": 45.6579, "lon": 25.6012, "rank": 2, "visitors": 1700000},
    {"name": "Constanța", "lat": 44.1733, "lon": 28.6383, "rank": 3, "visitors": 1350000},
    {"name": "Sibiu", "lat": 45.7983, "lon": 24.1256, "rank": 4, "visitors": 1250000},
    {"name": "Cluj-Napoca", "lat": 46.7712, "lon": 23.6236, "rank": 5, "visitors": 1150000},
    {"name": "Iași", "lat": 47.1585, "lon": 27.6014, "rank": 6, "visitors": 1000000},
    {"name": "Timișoara", "lat": 45.7489, "lon": 21.2087, "rank": 7, "visitors": 950000},
    {"name": "Oradea", "lat": 47.0465, "lon": 21.9189, "rank": 8, "visitors": 880000},
    {"name": "Suceava", "lat": 47.6514, "lon": 26.2556, "rank": 9, "visitors": 820000},
    {"name": "Sinaia", "lat": 45.3501, "lon": 25.5504, "rank": 10, "visitors": 770000},
    {"name": "Alba Iulia", "lat": 46.0741, "lon": 23.5781, "rank": 11, "visitors": 720000},
    {"name": "Târgu Mureș", "lat": 46.5425, "lon": 24.5575, "rank": 12, "visitors": 680000},
    {"name": "Baia Mare", "lat": 47.6573, "lon": 23.5681, "rank": 13, "visitors": 640000},
    {"name": "Arad", "lat": 46.1866, "lon": 21.3123, "rank": 14, "visitors": 600000},
    {"name": "Piatra Neamț", "lat": 46.9275, "lon": 26.3731, "rank": 15, "visitors": 560000},
    {"name": "Bistrița", "lat": 47.1351, "lon": 24.5002, "rank": 16, "visitors": 520000},
    {"name": "Râmnicu Vâlcea", "lat": 45.0997, "lon": 24.3693, "rank": 17, "visitors": 480000},
    {"name": "Craiova", "lat": 44.3302, "lon": 23.7949, "rank": 18, "visitors": 450000},
    {"name": "Deva", "lat": 45.8763, "lon": 22.9117, "rank": 19, "visitors": 420000},
    {"name": "Tulcea", "lat": 45.1716, "lon": 28.7918, "rank": 20, "visitors": 390000},
]

# Define colors based on rank
def get_color(rank):
    if 1 <= rank <= 5:
        return 'red'
    elif 6 <= rank <= 10:
        return 'blue'
    elif 11 <= rank <= 15:
        return 'green'
    else:
        return 'purple'

# Create base map centered on Romania
romania_map = folium.Map(location=[45.9432, 24.9668], zoom_start=6)

# Add markers with colors and popups
marker_cluster = MarkerCluster().add_to(romania_map)

for city in cities:
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=f"<b>{city['name']}</b><br>Rank: {city['rank']}<br>Visitors (2024): {city['visitors']:,}",
        icon=folium.Icon(color=get_color(city["rank"]))
    ).add_to(marker_cluster)

# Add legend with data source
legend_html = """
<div style="position: fixed; bottom: 50px; right: 50px; z-index:9999; background: white;
            padding: 10px; border: 2px solid gray; border-radius: 5px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3); font-size: 14px;">
    <b>City Rank Legend</b><br>
    <i class="fa fa-map-marker fa-2x" style="color:red"></i> Rank 1-5<br>
    <i class="fa fa-map-marker fa-2x" style="color:blue"></i> Rank 6-10<br>
    <i class="fa fa-map-marker fa-2x" style="color:green"></i> Rank 11-15<br>
    <i class="fa fa-map-marker fa-2x" style="color:purple"></i> Rank 16-20<br><br>
    <b>Data Source:</b><br>
    <span style="font-size: 12px;">Romanian National Institute of Statistics (2024)</span>
</div>
"""
romania_map.get_root().html.add_child(folium.Element(legend_html))

# Display the map
display(romania_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# !pip install openrouteservice folium

# %%
import folium
import openrouteservice
from folium.plugins import MarkerCluster
from IPython.display import display

# OpenRouteService API key (replace with your own)
ORS_API_KEY = "YOUR_ORS_API_KEY"

# Initialize ORS client
ors_client = openrouteservice.Client(key=ORS_API_KEY)

# City data (2024 visitors included)
cities = [
    {"name": "Bucharest", "lat": 44.4268, "lon": 26.1025, "rank": 1, "visitors": 2200000},
    {"name": "Brașov", "lat": 45.6579, "lon": 25.6012, "rank": 2, "visitors": 1700000},
    {"name": "Constanța", "lat": 44.1733, "lon": 28.6383, "rank": 3, "visitors": 1350000},
    {"name": "Sibiu", "lat": 45.7983, "lon": 24.1256, "rank": 4, "visitors": 1250000},
    {"name": "Cluj-Napoca", "lat": 46.7712, "lon": 23.6236, "rank": 5, "visitors": 1150000},
    {"name": "Iași", "lat": 47.1585, "lon": 27.6014, "rank": 6, "visitors": 1000000},
    {"name": "Timișoara", "lat": 45.7489, "lon": 21.2087, "rank": 7, "visitors": 950000},
    {"name": "Oradea", "lat": 47.0465, "lon": 21.9189, "rank": 8, "visitors": 880000},
    {"name": "Suceava", "lat": 47.6514, "lon": 26.2556, "rank": 9, "visitors": 820000},
    {"name": "Sinaia", "lat": 45.3501, "lon": 25.5504, "rank": 10, "visitors": 770000},
]

# Define colors based on rank
def get_color(rank):
    if 1 <= rank <= 5:
        return 'red'
    elif 6 <= rank <= 10:
        return 'blue'
    elif 11 <= rank <= 15:
        return 'green'
    else:
        return 'purple'

# Create the map centered on Romania
romania_map = folium.Map(location=[45.9432, 24.9668], zoom_start=6)

# Add markers
marker_cluster = MarkerCluster().add_to(romania_map)
for city in cities:
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=f"<b>{city['name']}</b><br>Rank: {city['rank']}<br>Visitors (2024): {city['visitors']:,}",
        icon=folium.Icon(color=get_color(city["rank"]))
    ).add_to(marker_cluster)

# Function to get route from Bucharest to city
def get_route(city):
    try:
        route = ors_client.directions(
            coordinates=[[26.1025, 44.4268], [city["lon"], city["lat"]]],
            profile='driving-car',
            format='geojson'
        )
        distance_km = route['routes'][0]['summary']['distance'] / 1000  # Convert meters to km
        duration_min = route['routes'][0]['summary']['duration'] / 60  # Convert seconds to minutes
        return route, round(distance_km, 1), round(duration_min, 0)
    except Exception as e:
        print(f"Error fetching route for {city['name']}: {e}")
        return None, None, None

# Add routes from Bucharest to each city
for city in cities:
    route, distance, duration = get_route(city)
    if route:
        # Extract route geometry
        coords = route['routes'][0]['geometry']['coordinates']
        route_coords = [(lat, lon) for lon, lat in coords]

        # Add route to the map
        folium.PolyLine(
            locations=route_coords,
            color="blue",
            weight=3,
            opacity=0.6,
            popup=f"{city['name']}: {distance} km, {duration} min"
        ).add_to(romania_map)

# Add legend with data source
legend_html = """
<div style="position: fixed; bottom: 50px; right: 50px; z-index:9999; background: white;
            padding: 10px; border: 2px solid gray; border-radius: 5px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3); font-size: 14px;">
    <b>City Rank Legend</b><br>
    <i class="fa fa-map-marker fa-2x" style="color:red"></i> Rank 1-5<br>
    <i class="fa fa-map-marker fa-2x" style="color:blue"></i> Rank 6-10<br>
    <i class="fa fa-map-marker fa-2x" style="color:green"></i> Rank 11-15<br>
    <i class="fa fa-map-marker fa-2x" style="color:purple"></i> Rank 16-20<br><br>
    <b>Routes</b>: Fastest from Bucharest<br>
    <b>Data Source:</b><br>
    <span style="font-size: 12px;">Romanian National Institute of Statistics (2024), OpenRouteService API</span>
</div>
"""
romania_map.get_root().html.add_child(folium.Element(legend_html))

# Display the map
display(romania_map)
# Out:
# Error fetching route for Bucharest: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Brașov: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Constanța: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Sibiu: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Cluj-Napoca: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Iași: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Timișoara: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Oradea: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Suceava: 403 ({'error': 'Access to this API has been disallowed'})
# Error fetching route for Sinaia: 403 ({'error': 'Access to this API has been disallowed'})
# ...

# %%
# !pip install googlemaps folium

# %%
import folium
import googlemaps
from folium.plugins import MarkerCluster
from IPython.display import display

# Google Maps API key (replace with your own)
GMAPS_API_KEY = "AIzaSyCLdJn3dme-n7OpgcMRhEcXiHaaz-eQNSM"

# Initialize Google Maps client
gmaps = googlemaps.Client(key=GMAPS_API_KEY)

# City data (2024 visitors included)
cities = [
    {"name": "Bucharest", "lat": 44.4268, "lon": 26.1025, "rank": 1, "visitors": 2200000},
    {"name": "Brașov", "lat": 45.6579, "lon": 25.6012, "rank": 2, "visitors": 1700000},
    {"name": "Constanța", "lat": 44.1733, "lon": 28.6383, "rank": 3, "visitors": 1350000},
    {"name": "Sibiu", "lat": 45.7983, "lon": 24.1256, "rank": 4, "visitors": 1250000},
    {"name": "Cluj-Napoca", "lat": 46.7712, "lon": 23.6236, "rank": 5, "visitors": 1150000},
]

# Define colors based on rank
def get_color(rank):
    if 1 <= rank <= 5:
        return 'red'
    elif 6 <= rank <= 10:
        return 'blue'
    elif 11 <= rank <= 15:
        return 'green'
    else:
        return 'purple'

# Create the map with Google Maps tiles
romania_map = folium.Map(
    location=[45.9432, 24.9668],
    zoom_start=6,
    tiles="https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}",
    attr='Google Maps'
)

# Add markers
marker_cluster = MarkerCluster().add_to(romania_map)
for city in cities:
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=f"<b>{city['name']}</b><br>Rank: {city['rank']}<br>Visitors (2024): {city['visitors']:,}",
        icon=folium.Icon(color=get_color(city["rank"]))
    ).add_to(marker_cluster)

# Function to get route from Bucharest to a city using Google Directions API
def get_route(city):
    try:
        directions = gmaps.directions(
            origin=(44.4268, 26.1025),  # Bucharest
            destination=(city["lat"], city["lon"]),
            mode="driving"
        )
        route = directions[0]["legs"][0]
        distance_km = route["distance"]["text"]
        duration_text = route["duration"]["text"]

        # Extract route coordinates
        polyline = route["steps"]
        route_coords = [
            (step["start_location"]["lat"], step["start_location"]["lng"]) for step in polyline
        ]
        route_coords.append((city["lat"], city["lon"]))  # Add final destination

        return route_coords, distance_km, duration_text
    except Exception as e:
        print(f"Error fetching route for {city['name']}: {e}")
        return None, None, None

# Add routes from Bucharest to each city
for city in cities:
    route_coords, distance, duration = get_route(city)
    if route_coords:
        folium.PolyLine(
            locations=route_coords,
            color="blue",
            weight=3,
            opacity=0.6,
            popup=f"{city['name']}: {distance}, {duration}"
        ).add_to(romania_map)

# Add legend with data source
legend_html = """
<div style="position: fixed; bottom: 50px; right: 50px; z-index:9999; background: white;
            padding: 10px; border: 2px solid gray; border-radius: 5px; box-shadow: 2px 2px 5px rgba(0,0,0,0.3); font-size: 14px;">
    <b>City Rank Legend</b><br>
    <i class="fa fa-map-marker fa-2x" style="color:red"></i> Rank 1-5<br>
    <i class="fa fa-map-marker fa-2x" style="color:blue"></i> Rank 6-10<br>
    <i class="fa fa-map-marker fa-2x" style="color:green"></i> Rank 11-15<br>
    <i class="fa fa-map-marker fa-2x" style="color:purple"></i> Rank 16-20<br><br>
    <b>Routes</b>: Fastest from Bucharest (Google Maps)<br>
    <b>Data Source:</b><br>
    <span style="font-size: 12px;">Romanian National Institute of Statistics (2024), Google Maps API</span>
</div>
"""
romania_map.get_root().html.add_child(folium.Element(legend_html))

# Display the map
display(romania_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
